# %%
import pandas as pd
import numpy as np
import os
import timeit
from tqdm.notebook import trange, tqdm

# %%
CHARTEVENTS_BY_ICUSTAY_ID = 'data/parquet/'
REDUCED_CE_BY_ICUSTAY_ID = 'data_demo/samples/'

# %%
chartevents_dir_list = os.listdir(REDUCED_CE_BY_ICUSTAY_ID)
len(chartevents_dir_list)
# Out:
# 6

# %%
test = pd.read_parquet(REDUCED_CE_BY_ICUSTAY_ID + chartevents_dir_list[5])
test = test.reset_index(drop=True)

# %% [markdown]
# ![Glascow](assets/images/GCS.jpg)
#
# https://www.firstaidforfree.com/glasgow-coma-scale-gcs-first-aiders/

# %% [markdown]
# |	Chart Event	|	Dim	|	Normal	| Initial dtype | Change to dtype |
# | --- | :--- | :--- | :--- | :--- |
# |	1. Glasgow coma scale eye opening	|	4	|	4 Spontaneously	| str | int |
# |	2. Glasgow coma scale verbal response	|	5	|	5 Oriented	| str | int |
# |	3. Glasgow coma scale motor response	|	6	|	6 Obeys Commands	| str | int |
# |	4. Glasgow coma scale total	|	13	|	15	| none/int | int |
# |	5. Capillary refill rate	|	2	|	Normal < 3 secs	| str | int |
# |	6. Diastolic blood pressure	|	1	|	70	| int | int |
# |	7. Systolic blood pressure	|	1	|	105	| int | int |
# |	8. Mean blood pressure	|	1	|	87.5	| int/float | int |
# |	9. Heart Rate	|	1	|	80	| int | int |
# |	10. Glucose	|	1	|	85	| int | int |
# |	11. Fraction inspired oxygen	|	1	|	0.21	| int/float | float? |
# |	12. Oxygen saturation	|	1	|	97.5	| int | int |
# |	13. Respiratory rate	|	1	|	15	| int | int |
# |	14. Body Temperature	|	1	|	37	| float | float |
# |	15. pH	|	1	|	7.4	| float | float |
# |	16. Weight	|	1	|	80.7	| float | float |
# |	17. Height	|	1	|	168.8	| float | float |
#
#
# Since there are so many `NaN` values, everything should just be a float?

# %%
test.iloc[:,0:34:2]
# Out:
#           GCS_EYE       GCS_MOTOR GCS_VERBAL GCS_TOTAL CAPILLARY_REFILL
# 0   Spontaneously  Obeys Commands   Oriented      None             None  \
# 1            None            None       None      None             None
# 2            None            None       None      None             None
# 3   Spontaneously  Obeys Commands   Oriented      None             None
# 4            None            None       None      None             None
# 5            None            None       None      None             None
# 6            None            None       None      None             None
# 7            None            None       None      None             None
# 8   Spontaneously  Obeys Commands   Oriented      None             None
# 9            None            None       None      None             None
# 10           None            None       None      None             None
# 11           None            None       None      None             None
# 12           None            None       None      None             None
# 13           None            None       None      None             None
# 14           None            None       None      None             None
# 15           None            None       None      None             None
# 16           None            None       None      None             None
# 17           None            None       None      None             None
# 18           None            None       None      None             None
# 19  Spontaneously  Obeys Commands   Oriented      None             None
# 20           None            None       None      None             None
# 21           None            None       None      None             None
# 22           None            None       None      None             None
# 23           None            None       None      None             None
# 24           None            None       None      None             None
# 25           None            None       None      None             None
# 26           None            None       None      None             None
# 27           None            None       None      None             None
# 28           None            None       None      None             None
# 29           None            None       None      None             None
# 30           None            None       None      None             None
# 31           None            None       None      None             None
# 32           None            None       None      None             None
# 33           None            None       None      None             None
# 34           None            None       None      None             None
# 35           None            None       None      None             None
# 36           None            None       None      None             None
# 37           None            None       None      None             None
# 38           None            None       None      None             None
# 39           None            None       None      None             None
# 40           None            None       None      None             None
# 41           None            None       None      None             None
# 42           None            None       None      None             None
# 43           None            None       None      None             None
# 44           None            None       None      None             None
# 45           None            None       None      None             None
# 46           None            None       None      None             None
# 47           None            None       None      None             None
#
#    D_BLOOD_PRESSURE M_BLOOD_PRESSURE S_BLOOD_PRESSURE HEART_RATE GLUCOSE
# 0                78               92              138        109     149  \
# 1                95              111              157        112    None
# 2                79               88              116         86    None
# 3                96              104              132         88     127
# 4               102              109              140         87    None
# 5                93              102              131         84    None
# 6               105              114              143         89    None
# 7                98              108              141         93    None
# 8                84               94              122         85    None
# 9                77               86              115         82     247
# 10              122              135              180        115    None
# 11               82               91              122         86    None
# 12               76               87              120         90    None
# 13               76               85              116         88    None
# 14               84               93              120         91    None
# 15               87               97              131         94     253
# 16               88               96              125         95    None
# 17               72               80              106         95    None
# 18               81               92              128        115    None
# 19             None             None             None        101    None
# 20               62               73              109         96    None
# 21               62               73              109         96    None
# 22               62               73              109         96    None
# 23               62               73              109         96    None
# 24               62               73              109         96    None
# 25               62               73              109         96    None
# 26               62               73              109         96    None
# 27               62               73              109         96    None
# 28               62               73              109         96    None
# 29               62               73              109         96    None
# 30               62               73              109         96    None
# 31               62               73              109         96    None
# 32               62               73              109         96    None
# 33               62               73              109         96    None
# 34               62               73              109         96    None
# 35               62               73              109         96    None
# 36               62               73              109         96    None
# 37               62               73              109         96    None
# 38               62               73              109         96    None
# 39               62               73              109         96    None
# 40               62               73              109         96    None
# 41               62               73              109         96    None
# 42               62               73              109         96    None
# 43               62               73              109         96    None
# 44               62               73              109         96    None
# 45               62               73              109         96    None
# 46               62               73              109         96    None
# 47               62               73              109         96    None
#
#    FRAC_OXYGEN O2_SAT RESP_RATE BODY_TEMP    PH WEIGHT HEIGHT
# 0         None     98        17        98  None   49.3   None
# 1         None     99        15      None  None   None   None
# 2         None     99         6      None  None   None   None
# 3         None     99        15      96.9  None   None   None
# 4         None     99         7      None  None   None   None
# 5         None    100         8      None  None   None   None
# 6         None     99         9      None  None   None   None
# 7         None     99        12      None  None   None   None
# 8         None     99        10      97.5  None   None   None
# 9         None     99        10      None  None   None   None
# 10        None    100        15      None  None   None   None
# 11        None    100        12      None  None  108.5   None
# 12        None    100        12      98.2  None   None   None
# 13        None     99        11      None  None   None   None
# 14        None     99        23      None  None   None   None
# 15        None    100        13      None  None   None   None
# 16        None     98        17      None  None   None   None
# 17        None   None        16      None  None   None   None
# 18        None     99        23      None  None   None   None
# 19        None     99        20      99.7  None   None   None
# 20        None     97        17      None  None   None   None
# 21        None     97        17      None  None   None   None
# 22        None     97        17      None  None   None   None
# 23        None     97        17      None  None   None   None
# 24        None     97        17      None  None   None   None
# 25        None     97        17      None  None   None   None
# 26        None     97        17      None  None   None   None
# 27        None     97        17      None  None   None   None
# 28        None     97        17      None  None   None   None
# 29        None     97        17      None  None   None   None
# 30        None     97        17      None  None   None   None
# 31        None     97        17      None  None   None   None
# 32        None     97        17      None  None   None   None
# 33        None     97        17      None  None   None   None
# 34        None     97        17      None  None   None   None
# 35        None     97        17      None  None   None   None
# 36        None     97        17      None  None   None   None
# 37        None     97        17      None  None   None   None
# 38        None     97        17      None  None   None   None
# 39        None     97        17      None  None   None   None
# 40        None     97        17      None  None   None   None
# 41        None     97        17      None  None   None   None
# 42        None     97        17      None  None   None   None
# 43        None     97        17      None  None   None   None
# 44        None     97        17      None  None   None   None
# 45        None     97        17      None  None   None   None
# 46        None     97        17      None  None   None   None
# 47        None     97        17      None  None   None   None

# %%
def gcs_eye_transform(x):
    if  x:
        pass

# %%
CHARTEVENTS_FILENAME = 'mimic-iii/CHARTEVENTS.csv'
READMISSION_FILENAME = 'data/readmission.csv'
SAMPLES_DIR = 'data/samples/'
DATASTORE_FILENAME = 'samples.h5'
FEATHER_EXT = '.feather'
ROWS_TO_READ = 1000000
MAX_ROWS_CHARTEVENTS = 330712483

skip_rows = 0

# %%
chartevents_columns = ["ROW_ID","SUBJECT_ID","HADM_ID","ICUSTAY_ID","ITEMID","CHARTTIME","STORETIME","CGID","VALUE","VALUENUM","VALUEUOM","WARNING","ERROR","RESULTSTATUS","STOPPED"]

# %%
event_to_id =[
{'CHAREVENT':'GCS_EYE', 'DESCRIPTION':'','ITEMID':[184, 220739],'UNIT':['NONE','NONE']},
{'CHAREVENT':'GCS_MOTOR', 'DESCRIPTION':'','ITEMID':[454, 223901],'UNIT':['NONE','NONE']},
{'CHAREVENT':'GCS_VERBAL', 'DESCRIPTION':'','ITEMID':[723, 223900],'UNIT':['NONE','NONE']},
{'CHAREVENT':'GCS_TOTAL', 'DESCRIPTION':'Sum of the 3 GCS events','ITEMID':[198],'UNIT':['NONE']},
]

# %%
chartevents_dtype = {'ROW_ID':object,
'SUBJECT_ID':object,
'HADM_ID':object,
'ICUSTAY_ID':object,
'ITEMID':object,
'CHARTTIME':object,
'STORETIME':object,
'CGID':object,
'VALUE':object,
'VALUENUM':object,
'VALUEUOM':object,
'WARNING':object,
'ERROR':object,
'RESULTSTATUS':object,
'STOPPED':object}

# %%
total = int(MAX_ROWS_CHARTEVENTS/ROWS_TO_READ)+1
eye_unique = []
motor_unique = []
verbal_unique = []
total_unique = []
with pd.read_csv(CHARTEVENTS_FILENAME,names=chartevents_columns,dtype=chartevents_dtype,skiprows=1,chunksize=ROWS_TO_READ) as file:
# chartevents = dd.read_csv(CHARTEVENTS_FILENAME,dtype=chartevents_dtype)
    for chartevents in tqdm(file,total=total):
        chartevents = chartevents.dropna(subset=['SUBJECT_ID','HADM_ID','ICUSTAY_ID','CHARTTIME','ITEMID']).drop('ROW_ID',axis=1)
        chartevents['ITEMID'] = chartevents['ITEMID'].astype(np.int64)
        eye_df = chartevents[(chartevents['ITEMID'].isin(event_to_id[0]['ITEMID']))]
        motor_df = chartevents[(chartevents['ITEMID'].isin(event_to_id[1]['ITEMID']))]
        verbal_df = chartevents[(chartevents['ITEMID'].isin(event_to_id[2]['ITEMID']))]
        total_df = chartevents[(chartevents['ITEMID'].isin(event_to_id[3]['ITEMID']))]

        eye_unique.extend(pd.unique(eye_df['VALUE']).tolist())
        motor_unique.extend(pd.unique(motor_df['VALUE']).tolist())
        verbal_unique.extend(pd.unique(verbal_df['VALUE']).tolist())
        total_unique.extend(pd.unique(total_df['VALUE']).tolist())

        # if len(eye_unique) > 0 or len(motor_unique) > 0 or len(verbal_unique) > 0 or len(total_unique) > 0:
        #     break
# Out:
#   0%|          | 0/331 [00:00<?, ?it/s]

# %%
import csv

# %%
with open('unique.txt', 'w') as f:
    w = csv.writer(f)
    w.writerow(eye_unique)
    w.writerow(motor_unique)
    w.writerow(verbal_unique)
    w.writerow(total_unique)

# %%
# import csv

# %%
gcs = []
with open('unique.txt', 'r') as f:
    r = csv.reader(f)
    for row in r:
        # print(row)
        gcs.append(row)

# %%
print(len(gcs[0]))
print(len(gcs[2]))
print(len(gcs[4]))
print(len(gcs[6]))
# Out:
# 1070
# 1537
# 1540
# 2224

# %%
eye_unique      = pd.unique(np.array(gcs[0]))
motor_unique    = pd.unique(np.array(gcs[2]))
verbal_unique   = pd.unique(np.array(gcs[4]))
total_unique    = pd.unique(np.array(gcs[6]))

# %%
print(len(eye_unique))
print(len(motor_unique))
print(len(verbal_unique))
print(len(total_unique))
# Out:
# 8
# 13
# 13
# 14

# %%
print(list(eye_unique))
print(list(motor_unique))
print(list(verbal_unique))
# Out:
# ['4 Spontaneously', '1 No Response', '2 To pain', '3 To speech', 'nan', 'To Speech', 'Spontaneously', 'To Pain']
# ['6 Obeys Commands', '5 Localizes Pain', '1 No Response', '4 Flex-withdraws', 'nan', '2 Abnorm extensn', '3 Abnorm flexion', 'Localizes Pain', 'Obeys Commands', 'Flex-withdraws', 'No response', 'Abnormal Flexion', 'Abnormal extension']
# ['5 Oriented', '1.0 ET/Trach', '4 Confused', '2 Incomp sounds', '1 No Response', 'nan', '3 Inapprop words', 'No Response-ETT', 'Oriented', 'No Response', 'Confused', 'Incomprehensible sounds', 'Inappropriate Words']

# %%
# # eye
# ['4 Spontaneously', '1 No Response', '2 To pain', '3 To speech', 'nan', 'To Speech', 'Spontaneously', 'To Pain']
# ['1 No Response', '2 To pain', '3 To speech','4 Spontaneously']
# #   1           2       3          4
# ['response', 'pain', 'speech', 'spont']

# # motor
# ['6 Obeys Commands', '5 Localizes Pain', '1 No Response', '4 Flex-withdraws', 'nan', '2 Abnorm extensn', '3 Abnorm flexion', 
#  'Localizes Pain', 'Obeys Commands', 'Flex-withdraws', 'No response', 'Abnormal Flexion', 'Abnormal extension']
# ['1 No Response', '2 Abnorm extension', '3 Abnormal flexion', '4 Flex-withdraws', '5 Localizes Pain', '6 Obeys Commands']

# #verbal
# [ '1.0 ET/Trach',   'nan',  'No Response-ETT', 'Oriented', 'No Response', 'Confused', 'Incomprehensible sounds', 'Inappropriate Words']
# ['1 No Response', '2 Incomp sounds', '3 Inapprop words','4 Confused', '5 Oriented',]
# ['1 No Response', '2 Incomprehensible sounds', '3 Inappropriate words','4 Confused', '5 Oriented',]

# pd.Series.str.startswith(pat, na=None)


gcs_eye_map     = {'__missing__': np.NaN, '4 Spontaneously': '4', '1 No Response': '1', '2 To pain': '2', '3 To speech': '3', 'To Speech': '3', 'Spontaneously': '4', 'To Pain': '2'}
gcs_motor_map   = {'__missing__': np.NaN, '6 Obeys Commands': '6', '5 Localizes Pain': '5', '1 No Response': '1', '4 Flex-withdraws': '4', '2 Abnorm extensn': '2', '3 Abnorm flexion': '3', 'Localizes Pain': '5', 
                    'Obeys Commands': '6', 'Flex-withdraws': '4', 'No response': '1', 'Abnormal Flexion': '3', 'Abnormal extension': '2'}
gcs_verbal_map  = {'__missing__': np.NaN, '5 Oriented': '5', '1.0 ET/Trach': '1', '4 Confused': '4', '2 Incomp sounds': '2', '1 No Response': '1', '3 Inapprop words': '3', 'No Response-ETT': '1', 
                    'Oriented': '5', 'No Response': '1', 'Confused': '4', 'Incomprehensible sounds': '2', 'Inappropriate Words': '3'}

# gcs = [
#     {'EYE':}
# ]
# 'spontaneously'

# %%
test = pd.read_parquet(REDUCED_CE_BY_ICUSTAY_ID + chartevents_dir_list[0])
test = test.reset_index(drop=True)
test['GCS_EYE'] = test['GCS_EYE'].map(gcs_eye_map).astype(np.float64)
test['GCS_MOTOR'] = test['GCS_MOTOR'].map(gcs_motor_map).astype(np.float64)
test['GCS_VERBAL'] = test['GCS_VERBAL'].map(gcs_verbal_map).astype(np.float64)
test['GCS_TOTAL'] = test['GCS_EYE'] + test['GCS_MOTOR'] + test['GCS_VERBAL']
test.iloc[:,0:7:2]
# Out:
#     GCS_EYE  GCS_MOTOR  GCS_VERBAL  GCS_TOTAL
# 0       NaN        NaN         NaN        NaN
# 1       NaN        NaN         NaN        NaN
# 2       4.0        6.0         5.0       15.0
# 3       NaN        NaN         NaN        NaN
# 4       NaN        NaN         NaN        NaN
# 5       NaN        NaN         NaN        NaN
# 6       4.0        6.0         5.0       15.0
# 7       NaN        NaN         NaN        NaN
# 8       NaN        NaN         NaN        NaN
# 9       NaN        NaN         NaN        NaN
# 10      4.0        6.0         5.0       15.0
# 11      NaN        NaN         NaN        NaN
# 12      NaN        NaN         NaN        NaN
# 13      4.0        6.0         5.0       15.0
# 14      NaN        NaN         NaN        NaN
# 15      NaN        NaN         NaN        NaN
# 16      NaN        NaN         NaN        NaN
# 17      4.0        6.0         5.0       15.0
# 18      NaN        NaN         NaN        NaN
# 19      NaN        NaN         NaN        NaN
# 20      NaN        NaN         NaN        NaN
# 21      4.0        6.0         5.0       15.0
# 22      NaN        NaN         NaN        NaN
# 23      4.0        6.0         5.0       15.0
# 24      NaN        NaN         NaN        NaN
# 25      NaN        NaN         NaN        NaN
# 26      NaN        NaN         NaN        NaN
# 27      NaN        NaN         NaN        NaN
# 28      4.0        6.0         5.0       15.0
# 29      NaN        NaN         NaN        NaN
# 30      NaN        NaN         NaN        NaN
# 31      NaN        NaN         NaN        NaN
# 32      4.0        6.0         5.0       15.0
# 33      NaN        NaN         NaN        NaN
# 34      NaN        NaN         NaN        NaN
# 35      NaN        NaN         NaN        NaN
# 36      4.0        6.0         5.0       15.0
# 37      NaN        NaN         NaN        NaN
# 38      NaN        NaN         NaN        NaN
# 39      4.0        6.0         5.0       15.0
# 40      NaN        NaN         NaN        NaN
# 41      NaN        NaN         NaN        NaN
# 42      NaN        NaN         NaN        NaN
# 43      NaN        NaN         NaN        NaN
# 44      4.0        6.0         5.0       15.0
# 45      NaN        NaN         NaN        NaN
# 46      NaN        NaN         NaN        NaN
# 47      4.0        6.0         5.0       15.0

# %%
test.dtypes
# Out:
# GCS_EYE                 float64
# GCS_EYE_ID              float64
# GCS_MOTOR               float64
# GCS_MOTOR_ID            float64
# GCS_VERBAL              float64
# GCS_VERBAL_ID           float64
# GCS_TOTAL               float64
# GCS_TOTAL_ID             object
# CAPILLARY_REFILL         object
# CAPILLARY_REFILL_ID     float64
# D_BLOOD_PRESSURE         object
# D_BLOOD_PRESSURE_ID     float64
# M_BLOOD_PRESSURE         object
# M_BLOOD_PRESSURE_ID     float64
# S_BLOOD_PRESSURE         object
# S_BLOOD_PRESSURE_ID     float64
# HEART_RATE               object
# HEART_RATE_ID           float64
# GLUCOSE                  object
# GLUCOSE_ID              float64
# FRAC_OXYGEN              object
# FRAC_OXYGEN_ID           object
# O2_SAT                   object
# O2_SAT_ID               float64
# RESP_RATE                object
# RESP_RATE_ID            float64
# BODY_TEMP                object
# BODY_TEMP_ID            float64
# PH                       object
# PH_ID                   float64
# WEIGHT                   object
# WEIGHT_ID               float64
# HEIGHT                   object
# HEIGHT_ID               float64
# GCS_EYE_IND               int64
# GCS_MOTOR_IND             int64
# GCS_VERBAL_IND            int64
# GCS_TOTAL_IND             int64
# CAPILLARY_REFILL_IND      int64
# D_BLOOD_PRESSURE_IND      int64
# M_BLOOD_PRESSURE_IND      int64
# S_BLOOD_PRESSURE_IND      int64
# HEART_RATE_IND            int64
# GLUCOSE_IND               int64
# FRAC_OXYGEN_IND           int64
# O2_SAT_IND                int64
# RESP_RATE_IND             int64
# BODY_TEMP_IND             int64
# PH_IND                    int64
# WEIGHT_IND                int64
# HEIGHT_IND                int64
# dtype: object

# %%
GCS_EYE                 float64
GCS_EYE_ID              float64
GCS_MOTOR               float64
GCS_MOTOR_ID            float64
GCS_VERBAL              float64
GCS_VERBAL_ID           float64
GCS_TOTAL               float64
GCS_TOTAL_ID             object
CAPILLARY_REFILL         object
CAPILLARY_REFILL_ID     float64
D_BLOOD_PRESSURE         object
D_BLOOD_PRESSURE_ID     float64
M_BLOOD_PRESSURE         object
M_BLOOD_PRESSURE_ID     float64
S_BLOOD_PRESSURE         object
S_BLOOD_PRESSURE_ID     float64
HEART_RATE               object
HEART_RATE_ID           float64
GLUCOSE                  object
GLUCOSE_ID              float64
FRAC_OXYGEN              object
FRAC_OXYGEN_ID           object
O2_SAT                   object
O2_SAT_ID               float64
RESP_RATE                object
RESP_RATE_ID            float64
BODY_TEMP                object
BODY_TEMP_ID            float64
PH                       object
PH_ID                   float64
WEIGHT                   object
WEIGHT_ID               float64
HEIGHT                   object
HEIGHT_ID               float64
GCS_EYE_IND               int64
GCS_MOTOR_IND             int64
GCS_VERBAL_IND            int64
GCS_TOTAL_IND             int64
CAPILLARY_REFILL_IND      int64
D_BLOOD_PRESSURE_IND      int64
M_BLOOD_PRESSURE_IND      int64
S_BLOOD_PRESSURE_IND      int64
HEART_RATE_IND            int64
GLUCOSE_IND               int64
FRAC_OXYGEN_IND           int64
O2_SAT_IND                int64
RESP_RATE_IND             int64
BODY_TEMP_IND             int64
PH_IND                    int64
WEIGHT_IND                int64
HEIGHT_IND                int64
dtype: object
